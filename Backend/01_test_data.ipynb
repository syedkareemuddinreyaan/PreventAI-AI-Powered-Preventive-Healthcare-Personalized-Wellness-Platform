# %% [markdown]
# # PreventAI – Test Data Module
#
# ## Purpose
# This notebook contains dummy prediction data and user information.
#
# It simulates the outputs that will eventually come from Member 1's machine learning models.
#
# This data will be used to develop and test:
# - Health Score Engine
# - Workout Recommendation Engine
# - Diet Recommendation Engine
# - Health Improvement Simulator

# %%
# ==========================================
# PreventAI - Dummy Prediction Data
# ==========================================

prediction_data = {
    "heart_risk": "Medium",
    "diabetes_risk": "Low",
    "obesity_status": "Obese",
    "sleep_risk": "Poor",
    "stress_risk": "Moderate"
}

# %%
# ==========================================
# PreventAI - Dummy User Information
# ==========================================

user_data = {
    "age": 21,
    "gender": "Male",
    "weight": 90,               # in kg
    "height": 175,              # in cm
    "activity_level": "Sedentary",
    "goal": "Weight Loss"
}

# %%
print("=== Prediction Data ===")

for key, value in prediction_data.items():
    print(f"{key}: {value}")
# Out:
# === Prediction Data ===
# heart_risk: Medium
# diabetes_risk: Low
# obesity_status: Obese
# sleep_risk: Poor
# stress_risk: Moderate

# %%
print("=== User Information ===")

for key, value in user_data.items():
    print(f"{key}: {value}")
# Out:
# === User Information ===
# age: 21
# gender: Male
# weight: 90
# height: 175
# activity_level: Sedentary
# goal: Weight Loss

# %%
print("Test Data Loaded Successfully!")
# Out:
# Test Data Loaded Successfully!
